# %% [markdown]
# <center><a href="https://www.nvidia.com/dli"> <img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/> </a></center>

# %% [markdown]
# # X03 - X03 Custom Videoprep Nodes
#
# **Workflow File:** `X03-Custom_videoprep_nodes.json`
#
# ---
#
# ## Overview
#
# Installation configuration for X03_custom_videoprep_nodes

# %% [markdown]
# ## Requirements
#
# | Requirement | Value |
# |-------------|-------|
# | **VRAM (Minimum)** | 16 GB |
# | **VRAM (Recommended)** | 24 GB |
# | **Custom Nodes** | 7 packages |
# | **Models** | 6 files |

# %% [markdown]
# ## Model Status Check
#
# Run the cell below to verify all required models are downloaded:

# %%
# Check install status using shared module
from shared.model_checker import check_models

# Workflow X03 status check
check_models("X03")

# %% [markdown]
# ## Launch Workflow
#
# Once ready, click below to open ComfyUI:

# %%
# %%js
# var hostname = window.location.hostname;
# var comfyUrl = "http://" + hostname + "/";
# var workflowFile = "X03-Custom_videoprep_nodes.json";
#
# var container = document.createElement('div');
# container.style.margin = '15px 0';
#
# var btn = document.createElement('a');
# btn.href = comfyUrl;
# btn.target = '_blank';
# btn.style.cssText = 'display: inline-block; background: #76b900; color: #000; padding: 12px 24px; border-radius: 5px; text-decoration: none; font-weight: bold;';
# btn.innerHTML = '🚀 Launch ComfyUI';
# container.appendChild(btn);
#
# var info = document.createElement('p');
# info.style.cssText = 'color: #888; font-size: 0.9em; margin-top: 10px;';
# info.innerHTML = '📁 Load workflow: <code>' + workflowFile + '</code>';
# container.appendChild(info);
#
# element.appendChild(container);

# %% [markdown]
# ---
#
# ## How to Use This Workflow
#
# ### Step 1: Load the Workflow
# 1. In ComfyUI, click **Workflows** icon
# 2. Select `X03-Custom_videoprep_nodes.json`
#
# ### Step 2: Run the Workflow
# Configure inputs as needed and click **Queue Prompt** to execute.
#
# ---
#
# ← [00 Introduction](00_Introduction.ipynb)
